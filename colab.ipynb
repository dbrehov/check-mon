# %%
repo_name = "check-mon"

# %%
# Проверка и установка окружения
# !npx playwright --version >/dev/null 2>&1 || (curl -fsSL https://deb.nodesource.com/setup_24.x | sudo -E bash - && sudo apt-get install -y node_js && sudo npm install -g typescript ts-node && npx playwright install --with-deps chromium && pip install yt-dlp)
# !node -v

# %%
# %%capture
# !ls
repo_url = f"https://github.com/dbrehov/{repo_name}.git"
# !git clone {repo_url}
# %cd {repo_name}
# !ls

# %%
# %%capture
# !npm i

# %%
# !xvfb-run -s "-screen 0 1920x1080x24" npx ts-node src/run.ts

# %%
# %%capture
# !git pull
