# %%
repo_name = "check-mon"

# %%
# %%capture
# Проверка: если playwright не установлен или не работает, ставим всё с нуля
# !npx playwright --version >/dev/null 2>&1 || (\n    curl -fsSL https://deb.nodesource.com/setup_24.x | sudo -E bash - && \n    sudo apt-get install -y nodejs && \n    sudo apt-get update && \n    sudo apt-get install -y libnss3 libatk1.0-0 libatk-bridge2.0-0 libcups2 libxkbcommon0 libxdamage1 libxcomposite1 libxrandr2 libxfixes3 libxext6 libx11-6 libglib2.0-0 libpango-1.0-0 libcairo2 libasound2 libatk1.0-data fonts-liberation wget xvfb && \n    sudo npm install -g typescript ts-node && \n    npx playwright install chromium && \n    pip install yt-dlp\n)
# !node -v

# %%
# %%capture
# !ls
repo_url = f"https://github.com/dbrehov/{repo_name}.git"
# !git clone {repo_url}
# %cd {repo_name}
# !ls

# %%
# %%capture
# !npm i

# %%
# !xvfb-run -s "-screen 0 1920x1080x24" npx ts-node src/run.ts

# %%
# %%capture
# !git pull
