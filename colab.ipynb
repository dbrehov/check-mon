# %%
repo_name = "check-mon"

# %%
# %%capture
# !ls
repo_url = f"https://github.com/dbrehov/{repo_name}.git"
# !git clone {repo_url}
# %cd {repo_name}
# !ls

# %%
# %%capture
# Установка Node.js 22
# !curl -fsSL https://deb.nodesource.com/setup_22.x | sudo -E bash -
# !sudo apt-get install -y nodejs

# TypeScript и ts-node
# !npm install -g typescript ts-node

# Установка Playwright и браузеров
# !npm install playwright
# !npx playwright install chromium

# Зависимости для Linux/Chromium
# !apt-get update
# !apt-get install -y \
    libnss3 libatk1.0-0 libatk-bridge2.0-0 libcups2 \
    libxkbcommon0 libxdamage1 libxcomposite1 libxrandr2 \
    libxfixes3 libxext6 libx11-6 libglib2.0-0 libpango-1.0-0 \
    libcairo2 libasound2 libatk1.0-data fonts-liberation wget xvfb

# !pip install yt-dlp > /dev/null

# %%
# %%capture
# !npm i

# %%
# !xvfb-run -s "-screen 0 1920x1080x24" npx ts-node src/run.ts
# Out:
# ⠙/content/check-mon/node_modules/ts-node/src/index.ts:859
#     return new TSError(diagnosticText, diagnosticCodes, diagnostics);
#            ^
# TSError: ⨯ Unable to compile TypeScript:
# src/run.ts:73:1 - error TS1128: Declaration or statement expected.
#
# 73 }
#    ~
#
#     at createTSError (/content/check-mon/node_modules/ts-node/src/index.ts:859:12)
#     at reportTSError (/content/check-mon/node_modules/ts-node/src/index.ts:863:19)
#     at getOutput (/content/check-mon/node_modules/ts-node/src/index.ts:1077:36)
#     at Object.compile (/content/check-mon/node_modules/ts-node/src/index.ts:1433:41)
#     at Module.m._compile (/content/check-mon/node_modules/ts-node/src/index.ts:1617:30)
#     at node:internal/modules/cjs/loader:1838:10
#     at Object.require.extensions.<computed> [as .ts] (/content/check-mon/node_modules/ts-node/src/index.ts:1621:12)
#     at Module.load (node:internal/modules/cjs/loader:1441:32)
#     at Function._load (node:internal/modules/cjs/loader:1263:12)
#     at TracingChannel.traceSync (node:diagnostics_channel:328:14) {
#   diagnosticCodes: [ 1128 ]
# }
# ⠙

# %%
# %%capture
# !git pull
